# %% [markdown]
# # Tuple

# %% [markdown]
# ###`Q1:` Join Tuples if similar initial element
# While working with Python tuples, we can have a problem in which we need to perform concatenation of records from the similarity of initial element. This problem can have applications in data domains such as Data Science.
#
# For eg.
# ```
# Input  : test_list = [(5, 6), (5, 7), (5, 8), (6, 10), (7, 13)]
# Output : [(5, 6, 7, 8), (6, 10), (7, 13)]
# ```

# %%
# write your code her
from collections import defaultdict
test_list = [(5, 6), (5, 7), (5, 8), (6, 10), (7, 13)]
a = defaultdict(list)
for key, value in test_list:

    a[key].append(value)

# Create the final list of tuples by unpacking each group
result = [(key, *values) for key, values in a.items()]
result
# Out:
# [(5, 6, 7, 8), (6, 10), (7, 13)]

# %%
test_list = [(5, 6), (5, 7), (5, 8), (6, 10), (7, 13)]
result_dict = {}

for key, value in test_list:
    if key in result_dict:
        result_dict[key].append(value)
    else:
        result_dict[key] = [value]
result = [(key, *values) for key, values in result_dict.items()]
print(result)
# Out:
# [(5, 6, 7, 8), (6, 10), (7, 13)]

# %% [markdown]
# ###`Q2:` Multiply Adjacent elements (both side) and take sum of right and lest side multiplication result.
#
#
# For eg.
# ```
# The original tuple : (1, 5, 7, 8, 10)
# Resultant tuple after multiplication :
#
# (1*5, 1*5+5*7, 7*5 + 7*8, 8*7 + 8*10, 10*8) -> (5, 40, 91, 136, 80)
#
# output-(5, 40, 91, 136, 80)
# ```

# %%
# write your code here
A = (1, 5, 7, 8, 10)

res = []
for i in range(len(A)):
  if i == 0:
    prod = A[i]*A[i+1]
  elif i == len(A)-1:
    prod = A[i]* A[i-1]
  else:
    prod = A[i]*A[i+1] + A[i]*A[i-1]
  res.append(prod)

tuple(res)
# Out:
# (5, 40, 91, 136, 80)

# %% [markdown]
# ###`Q3`: Check is tuples are same or not?
# Two tuples would be same if both tuples have same element at same index
# ```
# t1 = (1,2,3,0)
# t2 = (0,1,2,3)
#
# t1 and t2 are not same
# ```

# %%
# write your code here
t1 = tuple(input('enter'))
t2 = tuple(input('enter2'))

for i in (range(len(t1))):
  if t1[i] != t2[i]:
    print('t1 and t2 are not same')
    break
  else:
    print('t1 and t2 are same')
    break
# Out:
# enter1,2,3
# enter21,2,3
# t1 and t2 are same
# t1 and t2 are same
# t1 and t2 are same
# t1 and t2 are same
# t1 and t2 are same

# %% [markdown]
# ###`Q4`: Count no of tuples, list and set from a list
# ```
# list1 = [{'hi', 'bye'},{'Geeks', 'forGeeks'},('a', 'b'),['hi', 'bye'],['a', 'b']]
#
# ```
# `Output:`
#
# ```
# List-2
# Set-2
# Tuples-1
# ```

# %%
# write your code here
list1 = [{'hi', 'bye'},{'Geeks', 'forGeeks'},('a', 'b'),['hi', 'bye'],['a', 'b']]
list_count = 0
set_count = 0
tuple_count = 0
for item in list1:
    if isinstance(item, list):
        list_count += 1
    elif isinstance(item, set):
        set_count += 1
    elif isinstance(item, tuple):
        tuple_count += 1

print(f"List-{list_count}")
print(f"Set-{set_count}")
print(f"Tuples-{tuple_count}")
# Out:
# List-2
# Set-2
# Tuples-1

# %% [markdown]
# ###`Q5`: Shortlist Students for a Job role
# Ask user to input students record and store in tuples for each record. Then Ask user to input three things he wants in the candidate- Primary Skill, Higher Education, Year of Graduation.
#
# Show every students record in form of tuples if matches all required criteria.
#
# It is assumed that there will be only one primry skill.
#
# If no such candidate found, print `No such candidate`
#
# `Input:`
# ```
# Enter No of records- 2
# Enter Details of student-1
# Enter Student name- Manohar
# Enter Higher Education- B.Tech
# Enter Primary Skill- Python
# Enter Year of Graduation- 2022
# Enter Details of student-2
# Enter Student name- Ponian
# Enter Higher Education- B.Sc.
# Enter Primary Skill- C++
# Enter Year of Graduation- 2020
#
# Enter Job Role Requirement
# Enter Skill- Python
# Enter Higher Education- B.Tech
# Enter Year of Graduation- 2022
# ```
#
# `Output`
# ```
# ('Manohar', 'B.tech', 'Python', '2022')
# ```

# %%
# write your code here
a = int(input('enter name'))

# %% [markdown]
# # Set

# %% [markdown]
# ###`Q1:` Write a program to find set of common elements in three lists using sets.
# ```
# Input : ar1 = [1, 5, 10, 20, 40, 80]
#         ar2 = [6, 7, 20, 80, 100]
#         ar3 = [3, 4, 15, 20, 30, 70, 80, 120]
#
# Output : [80, 20]
# ```

# %%
# write your code here
ar1 = [1, 5, 10, 20, 40, 80]
ar2 = [6, 7, 20, 80, 100]
ar3 = [3, 4, 15, 20, 30, 70, 80, 120]
res = set(ar1) & set(ar2) & set(ar3)
list(res)
# Out:
# [80, 20]

# %% [markdown]
# ###`Q2:` Write a program to count unique number of vowels using sets in a given string. Lowercase and upercase vowels will be taken as different.
#
# `Input:`
# ```
# Str1 = "hands-on data science mentorship progrAm with live classes at affordable fee only on CampusX"
# ```
# `Output:`
# ```
# No of unique vowels-6
# ```

# %%
# write your code here
a ="hands-on data science mentorship progrAm with live classes at affordable fee only on CampusX"
vow = set('aeiouAEIOU')

res = {i for i in a if i in vow}
ans = len(res)
ans
# Out:
# 6

# %% [markdown]
# ### `Q3:` Write a program to Check if a given string is binary string of or not.
#
# A string is said to be binary if it's consists of only two unique characters.
#
# Take string input from user.
#
# ```
# Input: str = "01010101010"
# Output: Yes
#
# Input: str = "1222211"
# Output: Yes
#
# Input: str = "Campusx"
# Output: No
# ```

# %%
# write your code here
strr = '0101010101'
a = set(strr)
if len(a) == 2:
  print('yes')
else:
  print('no')
# Out:
# yes

# %% [markdown]
# ### `Q4`: find union of n arrays.
#
# **Example 1:**
#
# Input:
# ```bash
# [[1, 2, 2, 4, 3, 6],
#  [5, 1, 3, 4],
#  [9, 5, 7, 1],
#  [2, 4, 1, 3]]
# ```
#
# Output:
#
# ```bash
# [1, 2, 3, 4, 5, 6, 7, 9]
# ```

# %%
# write your code here
a = [[1, 2, 2, 4, 3, 6],
 [5, 1, 3, 4],
 [9, 5, 7, 1],
 [2, 4, 1, 3]]

res = set()
for i in a:
  res.update(i)

res
# Out:
# {1, 2, 3, 4, 5, 6, 7, 9}

# %% [markdown]
# ### `Q5`: Intersection of two lists. Intersection of two list means we need to take all those elements which are common to both of the initial lists and store them into another list. Only use using **list-comprehension**.
#
# **Example 1:**
#
# Input:
# ```bash
# lst1 = {15, 9, 10, 56, 23, 78, 5, 4, 9}
# lst2 = {9, 4, 5, 36, 47, 26, 10, 45, 87}
# ```
#
# Output:
# ```bash
# [9, 10, 4, 5]
# ```
#
# **Example 2:**
#
# Input:
# ```bash
# lst1 = {4, 9, 1, 17, 11, 26, 28, 54, 69}
# lst2 = {9, 9, 74, 21, 45, 11, 63, 28, 26}
# ```
#
# Output:
# ```bash
# [9, 11, 26, 28]
# ```

# %%
# write your code here
lst1 = {4, 9, 1, 17, 11, 26, 28, 54, 69}
lst2 = {9, 9, 74, 21, 45, 11, 63, 28, 26}
lst1.intersection_update(lst2)
list(lst1)
# Out:
# [9, 26, 11, 28]

# %% [markdown]
# # Dictionary

# %% [markdown]
# ### `Q1`: Key with maximum unique values
#
# Given a dictionary with values list, extract key whose value has most unique values.
#
# **Example 1:**
#
# Input:
#
# ```bash
# test_dict = {"CampusX" : [5, 7, 9, 4, 0], "is" : [6, 7, 4, 3, 3], "Best" : [9, 9, 6, 5, 5]}
# ```
#
# Output:
# ```bash
# CampusX
# ```
#
# **Example 2:**
#
# Input:
# ```bash
# test_dict = {"CampusX" : [5, 7, 7, 7, 7], "is" : [6, 7, 7, 7], "Best" : [9, 9, 6, 5, 5]}
# ```
#
# Output:
# ```bash
# Best
# ```

# %%
# write your code here
test_dict = {"all" : [5, 7, 7, 7, 7], "is" : [6, 7, 7, 7], "Best" : [9, 9, 6, 5, 5]}
a= []
for i , j in test_dict.items():
  a.append((i, len(set(j))))

sorted(a, key=(lambda x:x[1]))[-1][0]
# Out:
# 'Best'

# %% [markdown]
# ### `Q2`: Replace words from Dictionary. Given String, replace it’s words from lookup dictionary.
#
# **Example 1:**
#
# Input:
#
# ```bash
# test_str = 'CampusX best for DS students.'
# repl_dict = {"best" : "is the best channel", "DS" : "Data-Science"}
# ```
#
# Output:
#
# ```bash
# CampusX is the best channel for Data-Science students.
# ```
#
# **Example 2:**
#
# Input:
# ```bash
# test_str = 'CampusX best for DS students.'
# repl_dict = {"good" : "is the best channel", "ds" : "Data-Science"}
# ```
#
# Output:
# ```bash
# CampusX best for DS students.
# ```

# %%
def replace_words(test_str, repl_dict):
    # Split the string into words
    words = test_str.split()

    # Replace words based on the lookup dictionary
    for i, word in enumerate(words):
        # Check for the word in the dictionary (case-sensitive)
        if word in repl_dict:
            words[i] = repl_dict[word]

    # Join the words back into a string
    return ' '.join(words)

# Example 1
test_str1 = 'CampusX best for DS students.'
repl_dict1 = {"best": "is the best channel", "DS": "Data-Science"}
output1 = replace_words(test_str1, repl_dict1)
print(output1)
# Out:
# 'CampusX best for Data-Science students.CampusX is the best channel for DS students.CampusX best for Data-Science students.'

# %% [markdown]
# ### `Q3`: Convert List to List of dictionaries. Given list values and keys list, convert these values to key value pairs in form of list of dictionaries.
#
# **Example 1:**
#
# Input:
# ```bash
# test_list = ["DataScience", 3, "is", 8]
# key_list = ["name", "id"]
# ```
#
# Output:
#
# ```bash
# [{'name': 'DataScience', 'id': 3}, {'name': 'is', 'id': 8}]
# ```
#
# **Example 2:**
#
# Input:
# ```bash
# test_list = ["CampusX", 10]
# key_list = ["name", "id"]
# ```
#
# Output:
#
# ```bash
# [{'name': 'CampusX', 'id': 10}]
# ```

# %%
# write your code here
test_list = ["CampusX", 10]
key_list = ["name", "id"]
dict_list = []

for i in range(0, len(test_list), len(key_list)):
    dict_entry = {key_list[j]: test_list[i + j] for j in range(len(key_list))}
    dict_list.append(dict_entry)
dict_list
# Out:
# [{'name': 'CampusX', 'id': 10}]

# %% [markdown]
# ### `Q4`: Convert a list of Tuples into Dictionary.
#
# **Example 1:**
#
# Input:
# ```bash
# [("akash", 10), ("gaurav", 12), ("anand", 14), ("suraj", 20), ("akhil", 25), ("ashish", 30)]
# ```
#
# Output:
# ```bash
# {'akash': [10], 'gaurav': [12], 'anand': [14], 'suraj': [20], 'akhil': [25], 'ashish': [30]}
# ```
#
# **Example 2:**
#
# Input:
# ```bash
# [('A', 1), ('B', 2), ('C', 3)]
# ```
#
# Output:
# ```bash
# {'A': [1], 'B': [2], 'C': [3]}
# ```

# %%
# write your code here
a = [('A', 1), ('B', 2), ('C', 3)]
res = {}


for j in a:
    if j[0] in res:
      res[j[0]].append(list(j[1:]))
    else:
      res[j[0]] = list(j[1:])
res
# Out:
# {'A': [1], 'B': [2], 'C': [3]}

# %% [markdown]
# ### `Q5`: Sort Dictionary key and values List.
#
# **Example 1:**
#
# Input:
#
# ```bash
# {'c': [3], 'b': [12, 10], 'a': [19, 4]}
# ```
#
# Output:
#
# ```bash
# {'a': [4, 19], 'b': [10, 12], 'c': [3]}
# ```
#
# **Example 2:**
#
# Input:
#
# ```bash
# {'c': [10, 34, 3]}
# ```
#
# Output:
#
# ```bash
# {'c': [3, 10, 34]}
# ```

# %%
# write your code here
a = {'c': [3], 'b': [12, 10], 'a': [19, 4]}
res = {key:sorted(value) for key,value in sorted(a.items())}
res
# Out:
# {'a': [4, 19], 'b': [10, 12], 'c': [3]}
